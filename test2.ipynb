# %%
import numpy as np
import pandas as pd
import requests

# %%
request0 = requests.get("https://dcplatformstorageservice-prod-us-east-1.s3-accelerate.amazonaws.com/0f96f934b6c54c4991251b63bb531834_0CE41DEA648AA3890A495F94%40techacct.adobe.com/0976aa1e-d3ae-4f18-bee1-e261e7621ffd?X-Amz-Security-Token=FwoGZXIvYXdzEMr%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDBEd5pkF8ky138i6ISLUAdU1g%2B%2F8u%2FdvtyOFjts2oNrBCroKmSZk7hmiWN4rpP9CO5T2IKCWkJM7pEnjO%2B52wra3XqicNhUaW%2BimpnJHlTYq5TjmBa5N%2FmINX15GU9TxtHnXRcQDuqY%2FFDG0A%2BcmSddBQvUwJ147BG%2BODAC5IO87RIID1YHBbBKPvOJziLjstoF4082Ity1q5B698uneI3IUInDuNUXga8WqdqxF1GTMpkbu6rk%2B%2FfBEOoiBG41IdjP0257O7YHzAN7hynX2Q%2BcH%2B9A67b68TKm6JqM8r6rRz%2BqCKMWc3qQGMi1pG%2F2gDgEo3Gv4P4lHrTA2zasIpvUvZR05K1BoMf4%2F0LCtxssh4KwLWyy%2BLOg%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230625T005047Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=ASIAWD2N7EVPFQ27XK35%2F20230625%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=37c2ee35e07c612430e850ce07e683bbf37451416b3aba38ec98a1928798cabd")
print(request0.status_code)
doc = request0.json()
print(doc)
request1 = requests.get("https://dcplatformstorageservice-prod-us-east-1.s3-accelerate.amazonaws.com/0f96f934b6c54c4991251b63bb531834_0CE41DEA648AA3890A495F94%40techacct.adobe.com/614dc2a4-c23f-41a8-8ca2-a2b393b11599?X-Amz-Security-Token=FwoGZXIvYXdzEMr%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDMAuhUYsUQ34N%2B9WlCLUAf07Bu%2BT5XgjI2a%2B%2FdEgm9UQngJXgccY%2FXEVJxi4P5dpunhLkPpqJ%2Bg%2BLAe7zgwUS9zlT6OXTPhbNQ%2Ft3bM%2Bh8sc07jPEJ5%2BHOYSb9R5BKcaPVMqyhkUP9P6JsVTs30AGnDaE532rG9iCf6L4PCDGPAW8JiokHEUlt7sBY7USIFzpEgWPup6pJqWNoCA47qUZGRL9RYpx2m20%2BP7kVU4dszNK%2BU0fJdxPyXFc1oyBpyP0U5i%2FbeEwvy7YOKDqpUVJMc0WE6XiNn9Un26fpqwbO6s%2Fh2oKI%2Bc3qQGMi1zXLIldiN4WaO4P2ASKIHgsHKMYD306x05oL1taw8Yvy%2FAzE19A%2Ft1rj%2BKLBs%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230625T005146Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=ASIAWD2N7EVPNQWGIK4X%2F20230625%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=26fc2f19f8c0d41959179e404b86707f1d04e279f8d3f4040fc8e17119814145")
print(request1.status_code)
doc1 = request1.json()
print(doc1)
# Out:
# 200
# ...

# %%
list1 = doc["elements"]
print(len(list1))
list11 = doc1["elements"]
print(len(list11))
# Out:
# 96
# 118

# %%
ind = 0
count=0
indecies = [1,2,8,0,3,14,15,11,10,13,27,28,29,17,21,6,4,54]
list2=[]
for dic in list1 :
  if "Text" in list(dic.keys()) and ind in indecies:
      if dic["Text"][0]=="$" :
        count+=1

      list2.append(dic["Text"])
      print(ind,dic["Text"],"\n",dic["Path"])
  ind+=1
count-=3
print(count)
# Out:
# 0 NearBy Electronics
#  //Document/Sect/P
# 1 3741 Glory Road, Jamestown,
#  //Document/Sect/P[2]/Sub
# 2 Tennessee, USA
#  //Document/Sect/P[2]/Sub[2]
# 3 38556
#  //Document/Sect/P[2]/Sub[3]
# 4 Invoice# NL57EPAS7793742478
#  //Document/Sect/P[3]/Sub
# 6 12-05-2023
#  //Document/Sect/P[3]/Sub[3]
# 8 We are here to serve you better. Reach out to us in case of any concern or feedbacks.
#  //Document/Sect/P[4]
# 10 Willis Koelpin
#  //Document/Sect/P[6]/Sub
# 11 Willis_Koelpin4@yahoo.co
#  //Document/Sect/P[6]/Sub[2]
# 13 783-402-5895
#  //Document/Sect/P[6]/Sub[4]
# 14 353 Cara Shoals
#  //Document/Sect/P[6]/Sub[5]
# 15 Suchitlán
#  //Document/Sect/P[6]/Sub[6]
# 21 deserunt ex aliquip cillum est
#  //Document/Sect/Table/TR[2]/TD/P
# 29 ITEM
#  //Document/Sect/Table[2]/TR/TD/P
# 54 Small Fresh Salad
#  //Document/Sect/Table[3]/TR[3]/TD/P
# -3

# %%
ind = 0
count=0
indecies = [1,5,0,2,18,19,15,14,17,36,38,40,21,23,3,115]
list2=[]
for dic in list11 :
  if "Text" in list(dic.keys()) and ind in indecies:
      if dic["Text"][0]=="$" :
        count+=1

      list2.append(dic["Text"])
      print(ind,dic["Text"],"\n",dic["Path"])
  ind+=1
count-=3
print(count)
# Out:
# 0 NearBy Electronics
#  //Document/Sect/P
# 1 3741 Glory Road, Jamestown, Tennessee, USA
#  //Document/Sect/P[2]
# 2 38556
#  //Document/Sect/P[3]
# 3 Invoice# TG67TS4201156943079376302586 Issue date 12-05-2023
#  //Document/Sect/P[4]
# 5 We are here to serve you better. Reach out to us in case of any concern or feedbacks.
#  //Document/Sect/P[5]
# 14 Don Zulauf
#  //Document/Sect/Table/TR[2]/TD/P/Sub
# 15 Don_Zulauf40@hotmail.co
#  //Document/Sect/Table/TR[2]/TD/P/Sub[2]
# 17 110-825-4839
#  //Document/Sect/Table/TR[2]/TD/P/Sub[4]
# 18 121 Jacobs River
#  //Document/Sect/Table/TR[2]/TD/P/Sub[5]
# 19 Port-Vila
#  //Document/Sect/Table/TR[2]/TD/P/Sub[6]
# 21 veniam
#  //Document/Sect/Table/TR[2]/TD[2]/P
# 23 Due date: 08-07-2023
#  //Document/Sect/Table/TR[2]/TD[3]/P
# 36 Awesome Fresh Hat
#  //Document/Sect/Table[3]/TR/TD/P
# 38 28
#  //Document/Sect/Table[3]/TR/TD[2]/P
# 40 60
#  //Document/Sect/Table[3]/TR/TD[3]/P
# 115 10
#  //Document/Sect/Table[4]/TR[2]/TD[2]/P
# -3

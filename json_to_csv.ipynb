# %%
import numpy as np
import pandas as pd
import requests
import bs4 as bs

# %%
request0 = requests.get("https://dcplatformstorageservice-prod-us-east-1.s3-accelerate.amazonaws.com/0f96f934b6c54c4991251b63bb531834_0CE41DEA648AA3890A495F94%40techacct.adobe.com/30c10f77-12f9-47d5-9a26-7ccc3a60bf0f?X-Amz-Security-Token=FwoGZXIvYXdzEMr%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDCsa1MsQfwoZdPerQiLUASBeOysU8%2FOiBwwoinM5AIpBCgnfSn5b6RYfR1TrVbs5qpNdkiee%2FoNkOq0lkgC3AAMdBTm4J8ztsAI09zh%2FCpioDKHXZAtWptut5xKH8x5BXg3zX83p%2FUR9%2FaTVMf%2FFb3XpS5g9Cq5C3NgnYZ8%2Ffn%2BV7tHgFtiqcnvL%2BUAK0gLGYdphgtZqYJ8%2FHGdSzuLUw2O84iPlrMMFedct1V5QhPjj9c3qasxeMi%2BBndufVnl9LcJr5Yzw6m4jgVzz%2FD6n2Xu85YftDWEVtfb3zVUU1hL%2B%2BDuwKLaJ3qQGMi1ybcXFQ0gKIx%2B7kTTGPcGUOO3Jt514liyILp9f2U7JbwwAK0%2B2Io%2BrQJG0Tk8%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230625T001144Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=ASIAWD2N7EVPFMQB76MZ%2F20230625%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=3fa66d239c343cd9b8f613475839c3c8234f1c181abda2dfd4a8eea246e81f8b")

# %%
request0.status_code
# Out:
# 200

# %%
request1 = requests.get("https://dcplatformstorageservice-prod-us-east-1.s3-accelerate.amazonaws.com/0f96f934b6c54c4991251b63bb531834_0CE41DEA648AA3890A495F94%40techacct.adobe.com/6673761f-de27-4243-aacc-7e30028bf71b?X-Amz-Security-Token=FwoGZXIvYXdzEMr%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDCQQsgR%2FJ3mBNv5PoSLUAfBcaARR%2BCOYv%2B%2F2s3sCINzKa8ofCqvyS%2F17LzuA0CE8lMkXZt91nnnGVyWQ9JaM%2FhYvgRStqjjhFIXusJGE6hXMyPpv2zas20sjlSwZCkucb2TyQeZ7q%2BhsFGa5Q4UlUHfhp1BM5Mz%2FCCa7Kg4pZ7seyVpDszO9r6ogXNWbLMeRr9SIGbdReTH2cP8kEyvIaEzyJSJMeGNjLLGcF1Y9MiJFw5yjOc5sv9rOtpprAGt9Z%2F%2BbmcWVonWL%2Fp6Tt%2Fk2M0lGAQ%2F5t%2FpNgnJfUN1nrfFtvt4%2BKLuQ3qQGMi1GRO5Od2dDKG5CTGXQuWA1gUTSwcVFaTWoM3zj878%2BWNJT3oo1e8hm3NtmdCk%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20230625T002652Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=ASIAWD2N7EVPBMJKPF64%2F20230625%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=36c4005e48aa7b607887fe07e0aace9ae620bd81563273153613d3692c6d902c")
request1.status_code
# Out:
# 200

# %%
doc = request0.json()
print(doc)

list1 = []
# Out:
# {'version': {'json_export': '187', 'page_segmentation': '5', 'schema': '1.1.0', 'structure': '1.1036.0', 'table_structure': '5'}, 'extended_metadata': {'ID_instance': 'BB 5E AD C8 4F B7 B2 11 0A 00 67 45 8B 6B C6 23 ', 'ID_permanent': '36 34 20 39 35 20 41 41 20 43 38 20 34 46 20 42 37 20 42 32 20 31 31 20 30 41 20 30 30 20 36 37 20 34 35 20 38 42 20 36 42 20 43 36 20 32 33 20 ', 'pdf_version': '1.6', 'pdfa_compliance_level': '', 'is_encrypted': False, 'has_acroform': False, 'is_digitally_signed': False, 'pdfua_compliance_level': '', 'page_count': 2, 'has_embedded_files': False, 'is_certified': False, 'is_XFA': False, 'language': 'en-US'}, 'elements': [{'Bounds': [76.72799682617188, 734.4232025146484, 171.43968200683594, 743.8782348632812], 'ClipBounds': [76.72799682617188, 734.4232025146484, 171.43968200683594, 743.8782348632812], 'Font': {'alt_family_name': 'Arial', 'embedded': True, 'encoding': 'WinAnsiEncoding', 'family_name': 'Arial', 'font_type': 'TrueType', 'italic': False, 'm
# ...

# %%
doc1 = request1.json()
print(doc1)
# Out:
# {'version': {'json_export': '187', 'page_segmentation': '5', 'schema': '1.1.0', 'structure': '1.1036.0', 'table_structure': '5'}, 'extended_metadata': {'ID_instance': '5D 8A 21 CE 4F B7 B2 11 0A 00 67 45 8B 6B C6 23 ', 'ID_permanent': '31 34 20 30 35 20 31 36 20 43 45 20 34 46 20 42 37 20 42 32 20 31 31 20 30 41 20 30 30 20 36 37 20 34 35 20 38 42 20 36 42 20 43 36 20 32 33 20 ', 'pdf_version': '1.6', 'pdfa_compliance_level': '', 'is_encrypted': False, 'has_acroform': False, 'is_digitally_signed': False, 'pdfua_compliance_level': '', 'page_count': 2, 'has_embedded_files': False, 'is_certified': False, 'is_XFA': False, 'language': 'en-US'}, 'elements': [{'Bounds': [76.72799682617188, 734.4232025146484, 171.43968200683594, 743.8782348632812], 'ClipBounds': [76.72799682617188, 734.4232025146484, 171.43968200683594, 743.8782348632812], 'Font': {'alt_family_name': 'Arial', 'embedded': True, 'encoding': 'WinAnsiEncoding', 'family_name': 'Arial', 'font_type': 'TrueType', 'italic': False, 'm
# ...

# %%
list1 = doc["elements"]
print(len(list1))
# Out:
# 96

# %%
list11 = doc1["elements"]
print(len(list11))
# Out:
# 118

# %%
ind = 0
count=0
list2=[]
for dic in list1 :
  if "Text" in list(dic.keys()) and "Text" in list(dic1.keys()):
      if dic["Text"][0]=="$" :
        count+=1

      list2.append(dic["Text"])
      print(ind,dic["Text"])
  ind+=1
count-=3
print(count)
# Out:
# 0 NearBy Electronics
# 1 3741 Glory Road, Jamestown,
# 2 Tennessee, USA
# 3 38556
# 4 Invoice# NL57EPAS7793742478
# 5 Issue date
# 6 12-05-2023
# 7 NearBy Electronics
# 8 We are here to serve you better. Reach out to us in case of any concern or feedbacks.
# 9 BILL TO
# 10 Willis Koelpin
# 11 Willis_Koelpin4@yahoo.co
# 12 m
# 13 783-402-5895
# 14 353 Cara Shoals
# 15 Suchitlán
# 16 DETAILS
# 19 minim velit velit fugiat culpa
# 21 deserunt ex aliquip cillum est
# 23 aliqua ex amet amet
# 24 PAYMENT
# 25 Due date: 08-07-2023
# 26 $22337.7
# 29 ITEM
# 31 QTY
# 33 RATE
# 35 AMOUNT
# 38 Rustic Rubber Gloves
# 40 102
# 42 29
# 44 $2958
# 46 Fantastic Granite Salad
# 48 39
# 50 27
# 52 $1053
# 54 Small Fresh Salad
# 56 95
# 58 69
# 60 $6555
# 62 Fantastic Metal Chips
# 64 67
# 66 49
# 68 $3283
# 70 Refined Cotton Pants
# 72 79
# 74 72
# 76 $5688
# 78 Ergonomic Concrete Towels
# 80 35
# 82 22
# 84 $770
# 87 Subtotal
# 89 $20307
# 91 Tax %
# 93 10
# 94 Total Due
# 95 $22337.7
# 6

# %%
print(list2[21][list2[21].find(":")+2:])
print(list2[4][list2[4].find("#")+2:])
# Out:
# 08-07-2023
# NL57EPAS7793742478

# %%
csv_headers = ["Bussiness__City","Bussiness__Country","Bussiness__Description","Bussiness__Name","Bussiness__StreetAddress","Bussiness__Zipcode","Customer__Address__line1","Customer__Address__line2","Customer__Email","Customer__Name","Customer__PhoneNumber"\
,"Invoice__BillDetails__Name","Invoice__BillDetails__Quantity","Invoice__BillDetails__Rate","Invoice__Description","Invoice__DueDate","Invoice__IssueDate","Invoice__Number","Invoice__Tax"]

# %%
df = pd.DataFrame(columns = csv_headers)


var=list2[1].split(",")
list_com =[]
list_com.append(var[1].strip())
list_com.append(list2[2])
list_com.append(list2[8])
list_com.append(list2[0])
list_com.append(var[0].strip())
list_com.append(list2[3])
list_com.append(list2[14])
list_com.append(list2[15])
list_com.append(list2[11])
list_com.append(list2[10])
list_com.append(list2[13])
desc = list2[17] + list2[18] + list2[19]
q = 27
for i in range(count) :
  templist = []
  templist.extend(list_com)
  templist.append(list2[q])
  templist.append(list2[q+1])
  templist.append(list2[q+2])
  templist.append(desc)
  templist.append(list2[21][list2[21].find(":")+2:])
  templist.append(list2[6])
  templist.append(list2[4][list2[4].find("#")+2:])
  templist.append(list2[54])
  df.loc[len(df.index)] = templist
  #print(len(templist))
  q+=4

print(df)
# Out:
#   Bussiness__City Bussiness__Country  \
# 0       Jamestown    Tennessee, USA
# 1       Jamestown    Tennessee, USA
# 2       Jamestown    Tennessee, USA
# 3       Jamestown    Tennessee, USA
# 4       Jamestown    Tennessee, USA
# 5       Jamestown    Tennessee, USA
#
#                               Bussiness__Description      Bussiness__Name  \
# 0  We are here to serve you better. Reach out to ...  NearBy Electronics
# 1  We are here to serve you better. Reach out to ...  NearBy Electronics
# 2  We are here to serve you better. Reach out to ...  NearBy Electronics
# 3  We are here to serve you better. Reach out to ...  NearBy Electronics
# 4  We are here to serve you better. Reach out to ...  NearBy Electronics
# 5  We are here to serve you better. Reach out to ...  NearBy Electronics
#
#   Bussiness__StreetAddress Bussiness__Zipcode Customer__Address__line1  \
# 0          3741 Glory Road             38556          353 Cara Shoals
# ...

# %%
df.to_csv("result_test.csv")

# %%
print(len(csv_headers))
# Out:
# 19
